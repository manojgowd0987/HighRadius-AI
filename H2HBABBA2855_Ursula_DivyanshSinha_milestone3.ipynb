# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Reading Dataset

# %%
df = pd.read_csv("C:/Users/rajeev/Downloads/H2HBABBA2855.csv")

# %%
df.dtypes # checking data types
# Out:
# business_code              object
# cust_number                object
# name_customer              object
# clear_date                 object
# buisness_year             float64
# doc_id                    float64
# posting_date               object
# document_create_date        int64
# document_create_date.1      int64
# due_in_date               float64
# invoice_currency           object
# document type              object
# posting_id                float64
# area_business             float64
# total_open_amount         float64
# baseline_create_date      float64
# cust_payment_terms         object
# invoice_id                float64
# isOpen                      int64
# dtype: object

# %%
df.head()
# Out:
#   business_code cust_number         name_customer           clear_date  \
# 0          U001  0200782669      SYGMA associates  2019-10-25 00:00:00
# 1          U001  0200778998         CE associates  2019-03-08 00:00:00
# 2          U001  0100014187       GAD  foundation  2019-09-03 00:00:00
# 3          U001  0200772670  ASSOCIAT corporation  2019-01-29 00:00:00
# 4          U001  0200705742                DOT co  2020-02-10 00:00:00
#
#    buisness_year        doc_id posting_date  document_create_date  \
# 0         2019.0  1.929956e+09   2019-10-09              20191003
# 1         2019.0  1.928824e+09   2019-02-21              20190220
# 2         2019.0  1.929735e+09   2019-08-13              20190812
# 3         2019.0  1.928616e+09   2019-01-14              20190114
# 4         2020.0  1.930437e+09   2020-01-24              20200124
#
#    document_create_date.1  due_in_date invoice_currency document type  \
# 0                20191009   20191024.0              USD            RV
# 1                20190221   20190308.0              USD            RV
# 2                20190813   20190902.0              USD            RV
# 3                20190114   20190129.0              USD            RV
# 4                20200124   20200225.0              USD            RV
#
#    posting_id  area_business  total_open_amount  baseline_create_date  \
# 0         1.0            NaN            3311.27            20191009.0
# 1         1.0            NaN           95728.31            20190221.0
# 2         1.0            NaN           70306.33            20190813.0
# 3         1.0            NaN           72046.76            20190114.0
# 4         1.0            NaN             864.53            20200124.0
#
#   cust_payment_terms    invoice_id  isOpen
# 0               NAA8  1.929956e+09       0
# 1               NAA8  1.928824e+09       0
# 2               NAD1  1.929735e+09       0
# 3               NAU5  1.928616e+09       0
# 4               NA32  1.930437e+09       0

# %%
df.shape # checking shapes
# Out:
# (50000, 19)

# %% [markdown]
# ## Spliting dataset into train and final-test

# %%
# spliting data according to null values in clear_date
test_data = df[df.clear_date.isnull()]  # this will be the final testing dataset

# %%
test_data.shape # testing data has 10000 rows
# Out:
# (10000, 19)

# %%
# removing null columns from clear_date of training dataset 
df = df[df.clear_date.notnull()]

# %%
df.shape # training data has 40000 rows
# Out:
# (40000, 19)

# %% [markdown]
# ## Convert all dates to date format

# %%
# converting all dates to timedate format
df['clear_date'] = pd.to_datetime(df.clear_date)
df['posting_date'] = pd.to_datetime(df.posting_date)
df.head()

df['document_create_date'] = pd.to_datetime(df['document_create_date'], format='%Y%m%d')
df['document_create_date.1'] = pd.to_datetime(df['document_create_date.1'], format='%Y%m%d')

df['due_in_date'] = df['due_in_date'].astype(int)
df['baseline_create_date'] = df['baseline_create_date'].astype(int)

df['due_in_date'] = pd.to_datetime(df['due_in_date'], format='%Y%m%d')
df['baseline_create_date'] = pd.to_datetime(df['baseline_create_date'], format='%Y%m%d')
df.head()
# Out:
#   business_code cust_number         name_customer clear_date  buisness_year  \
# 0          U001  0200782669      SYGMA associates 2019-10-25         2019.0
# 1          U001  0200778998         CE associates 2019-03-08         2019.0
# 2          U001  0100014187       GAD  foundation 2019-09-03         2019.0
# 3          U001  0200772670  ASSOCIAT corporation 2019-01-29         2019.0
# 4          U001  0200705742                DOT co 2020-02-10         2020.0
#
#          doc_id posting_date document_create_date document_create_date.1  \
# 0  1.929956e+09   2019-10-09           2019-10-03             2019-10-09
# 1  1.928824e+09   2019-02-21           2019-02-20             2019-02-21
# 2  1.929735e+09   2019-08-13           2019-08-12             2019-08-13
# 3  1.928616e+09   2019-01-14           2019-01-14             2019-01-14
# 4  1.930437e+09   2020-01-24           2020-01-24             2020-01-24
#
#   due_in_date invoice_currency document type  posting_id  area_business  \
# 0  2019-10-24              USD            RV         1.0            NaN
# 1  2019-03-08              USD            RV         1.0            NaN
# 2  2019-09-02              USD            RV         1.0            NaN
# 3  2019-01-29              USD            RV         1.0            NaN
# 4  2020-02-25              USD            RV         1.0            NaN
#
#    total_open_amount baseline_create_date cust_payment_terms    invoice_id  \
# 0            3311.27           2019-10-09               NAA8  1.929956e+09
# 1           95728.31           2019-02-21               NAA8  1.928824e+09
# 2           70306.33           2019-08-13               NAD1  1.929735e+09
# 3           72046.76           2019-01-14               NAU5  1.928616e+09
# 4             864.53           2020-01-24               NA32  1.930437e+09
#
#    isOpen
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
# using to ordinal function to convert time date to proleptic Gregorian ordinal (no. of days from 01/01/01 to current date)
df['clear_date']=df['clear_date'].map(dt.datetime.toordinal)
df['posting_date']=df['posting_date'].map(dt.datetime.toordinal)
df['document_create_date']=df['document_create_date'].map(dt.datetime.toordinal)
df['document_create_date.1']=df['document_create_date.1'].map(dt.datetime.toordinal)
df['due_in_date']=df['due_in_date'].map(dt.datetime.toordinal)
df['baseline_create_date']=df['baseline_create_date'].map(dt.datetime.toordinal)

# %%
df.dtypes
# Out:
# business_code              object
# cust_number                object
# name_customer              object
# clear_date                  int64
# buisness_year             float64
# doc_id                    float64
# posting_date                int64
# document_create_date        int64
# document_create_date.1      int64
# due_in_date                 int64
# invoice_currency           object
# document type              object
# posting_id                float64
# area_business             float64
# total_open_amount         float64
# baseline_create_date        int64
# cust_payment_terms         object
# invoice_id                float64
# isOpen                      int64
# dtype: object

# %%
df.head()
# Out:
#   business_code cust_number         name_customer  clear_date  buisness_year  \
# 0          U001  0200782669      SYGMA associates      737357         2019.0
# 1          U001  0200778998         CE associates      737126         2019.0
# 2          U001  0100014187       GAD  foundation      737305         2019.0
# 3          U001  0200772670  ASSOCIAT corporation      737088         2019.0
# 4          U001  0200705742                DOT co      737465         2020.0
#
#          doc_id  posting_date  document_create_date  document_create_date.1  \
# 0  1.929956e+09        737341                737335                  737341
# 1  1.928824e+09        737111                737110                  737111
# 2  1.929735e+09        737284                737283                  737284
# 3  1.928616e+09        737073                737073                  737073
# 4  1.930437e+09        737448                737448                  737448
#
#    due_in_date invoice_currency document type  posting_id  area_business  \
# 0       737356              USD            RV         1.0            NaN
# 1       737126              USD            RV         1.0            NaN
# 2       737304              USD            RV         1.0            NaN
# 3       737088              USD            RV         1.0            NaN
# 4       737480              USD            RV         1.0            NaN
#
#    total_open_amount  baseline_create_date cust_payment_terms    invoice_id  \
# 0            3311.27                737341               NAA8  1.929956e+09
# 1           95728.31                737111               NAA8  1.928824e+09
# 2           70306.33                737284               NAD1  1.929735e+09
# 3           72046.76                737073               NAU5  1.928616e+09
# 4             864.53                737448               NA32  1.930437e+09
#
#    isOpen
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %% [markdown]
# ## Sorting database according to posting_date

# %%
df['posting_date'].dtype
# Out:
# dtype('int64')

# %%
df.sort_values(['posting_date'],inplace=True,ignore_index=True) # sorting data as per posting_data

# %%
df.head(5)
# Out:
#   business_code cust_number       name_customer  clear_date  buisness_year  \
# 0          U001  0200779906            BOZZU in      737075         2019.0
# 1          U001  0200769623        WAL-MAR corp      737070         2019.0
# 2          U001  0200769623  WAL-MAR foundation      737068         2019.0
# 3          U001  0200769623            WAL-MAR       737068         2019.0
# 4          U001  0200762301          C&S WH llc      737074         2019.0
#
#          doc_id  posting_date  document_create_date  document_create_date.1  \
# 0  1.928543e+09        737058                737058                  737058
# 1  1.928543e+09        737058                737058                  737058
# 2  1.928541e+09        737058                737057                  737058
# 3  1.928538e+09        737058                737057                  737058
# 4  1.928540e+09        737058                737057                  737058
#
#    due_in_date invoice_currency document type  posting_id  area_business  \
# 0       737073              USD            RV         1.0            NaN
# 1       737073              USD            RV         1.0            NaN
# 2       737073              USD            RV         1.0            NaN
# 3       737073              USD            RV         1.0            NaN
# 4       737073              USD            RV         1.0            NaN
#
#    total_open_amount  baseline_create_date cust_payment_terms    invoice_id  \
# 0           94123.08                737058               NAA8  1.928543e+09
# 1           45645.00                737058               NAH4  1.928543e+09
# 2            8286.44                737058               NAH4  1.928541e+09
# 3           51600.07                737058               NAH4  1.928538e+09
# 4           13866.83                737058               NAC6  1.928540e+09
#
#    isOpen
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %% [markdown]
# ## Removing null values from training dataset

# %%
df.isnull().sum() # number of null values in the dataset
# Out:
# business_code                 0
# cust_number                   0
# name_customer                 0
# clear_date                    0
# buisness_year                 0
# doc_id                        0
# posting_date                  0
# document_create_date          0
# document_create_date.1        0
# due_in_date                   0
# invoice_currency              0
# document type                 0
# posting_id                    0
# area_business             40000
# total_open_amount             0
# baseline_create_date          0
# cust_payment_terms            0
# invoice_id                    5
# isOpen                        0
# dtype: int64

# %%
df.isnull().mean()
# Out:
# business_code             0.000000
# cust_number               0.000000
# name_customer             0.000000
# clear_date                0.000000
# buisness_year             0.000000
# doc_id                    0.000000
# posting_date              0.000000
# document_create_date      0.000000
# document_create_date.1    0.000000
# due_in_date               0.000000
# invoice_currency          0.000000
# document type             0.000000
# posting_id                0.000000
# area_business             1.000000
# total_open_amount         0.000000
# baseline_create_date      0.000000
# cust_payment_terms        0.000000
# invoice_id                0.000125
# isOpen                    0.000000
# dtype: float64

# %%
df.drop(columns=['area_business'],inplace=True) # droping area_business because whole column is empty

# %%
df.isnull().sum()
# Out:
# business_code             0
# cust_number               0
# name_customer             0
# clear_date                0
# buisness_year             0
# doc_id                    0
# posting_date              0
# document_create_date      0
# document_create_date.1    0
# due_in_date               0
# invoice_currency          0
# document type             0
# posting_id                0
# total_open_amount         0
# baseline_create_date      0
# cust_payment_terms        0
# invoice_id                5
# isOpen                    0
# dtype: int64

# %%
df.dropna(subset=["invoice_id"],inplace=True) # removing rows with null values of the column invoice_id

# %%
df.shape
# Out:
# (39995, 18)

# %%
df.isnull().sum()
# Out:
# business_code             0
# cust_number               0
# name_customer             0
# clear_date                0
# buisness_year             0
# doc_id                    0
# posting_date              0
# document_create_date      0
# document_create_date.1    0
# due_in_date               0
# invoice_currency          0
# document type             0
# posting_id                0
# total_open_amount         0
# baseline_create_date      0
# cust_payment_terms        0
# invoice_id                0
# isOpen                    0
# dtype: int64

# %% [markdown]
# ## Removing Duplicates

# %%
# Removing duplicates from rows
df.duplicated().sum() #print no. of duplicated values
# Out:
# 827

# %%
df.loc[df.duplicated(),:]
# Out:
#       business_code cust_number  name_customer  clear_date  buisness_year  \
# 104            U001  0200799367        MCL llc      737074         2019.0
# 164            U001  0200769623     WAL-MAR co      737070         2019.0
# 257            U001  0200718130       SYSCO F       737077         2019.0
# 381            U001  0200759878  SA foundation      737081         2019.0
# 386            U001  0200762950    HAR systems      737077         2019.0
# ...             ...         ...            ...         ...            ...
# 39824          U001  0200769623    WAL-MAR llc      737501         2020.0
# 39853          U001  0200337148      COAS corp      737495         2020.0
# 39924          U001  0200769623  WAL-MAR trust      737493         2020.0
# 39954          U001  0200725421        BEN  in      737495         2020.0
# 39973          U001  0200794332   COST systems      737495         2020.0
#
#              doc_id  posting_date  document_create_date  \
# 104    1.928543e+09        737059                737058
# 164    1.928543e+09        737060                737058
# 257    1.928550e+09        737062                737061
# 381    1.928549e+09        737063                737060
# 386    1.928550e+09        737063                737061
# ...             ...           ...                   ...
# 39824  1.930559e+09        737480                737478
# 39853  1.930571e+09        737480                737481
# 39924  1.930566e+09        737481                737480
# 39954  1.930566e+09        737481                737480
# 39973  1.930572e+09        737481                737481
#
#        document_create_date.1  due_in_date invoice_currency document type  \
# 104                    737059       737074              USD            RV
# 164                    737060       737075              USD            RV
# 257                    737062       737077              USD            RV
# 381                    737063       737078              USD            RV
# 386                    737063       737078              USD            RV
# ...                       ...          ...              ...           ...
# 39824                  737480       737495              USD            RV
# 39853                  737480       737495              USD            RV
# 39924                  737481       737496              USD            RV
# 39954                  737481       737496              USD            RV
# 39973                  737481       737496              USD            RV
#
#        posting_id  total_open_amount  baseline_create_date cust_payment_terms  \
# 104           1.0           96589.32                737059               NAA8
# 164           1.0           17249.88                737060               NAH4
# 257           1.0            7068.08                737062               NAA8
# 381           1.0           21330.50                737063               NAH4
# 386           1.0          127017.88                737063               NAA8
# ...           ...                ...                   ...                ...
# 39824         1.0            8328.33                737480               NAH4
# 39853         1.0           67924.87                737480               NAA8
# 39924         1.0            1898.90                737481               NAH4
# 39954         1.0           29860.41                737481               NAA8
# 39973         1.0           35888.33                737481               NAAX
#
#          invoice_id  isOpen
# 104    1.928543e+09       0
# 164    1.928543e+09       0
# 257    1.928550e+09       0
# 381    1.928549e+09       0
# 386    1.928550e+09       0
# ...             ...     ...
# 39824  1.930559e+09       0
# 39853  1.930571e+09       0
# 39924  1.930566e+09       0
# 39954  1.930566e+09       0
# 39973  1.930572e+09       0
#
# [827 rows x 18 columns]

# %%
df.drop_duplicates(keep='first',inplace=True) # droping duplicate values

# %%
df.shape
# Out:
# (39168, 18)

# %%
df.dtypes
# Out:
# business_code              object
# cust_number                object
# name_customer              object
# clear_date                  int64
# buisness_year             float64
# doc_id                    float64
# posting_date                int64
# document_create_date        int64
# document_create_date.1      int64
# due_in_date                 int64
# invoice_currency           object
# document type              object
# posting_id                float64
# total_open_amount         float64
# baseline_create_date        int64
# cust_payment_terms         object
# invoice_id                float64
# isOpen                      int64
# dtype: object

# %% [markdown]
# ## Removing constant features

# %%
#  Applying variance threshold
from sklearn.feature_selection import VarianceThreshold

# %%
df.head()
# Out:
#   business_code cust_number       name_customer  clear_date  buisness_year  \
# 0          U001  0200779906            BOZZU in      737075         2019.0
# 1          U001  0200769623        WAL-MAR corp      737070         2019.0
# 2          U001  0200769623  WAL-MAR foundation      737068         2019.0
# 3          U001  0200769623            WAL-MAR       737068         2019.0
# 4          U001  0200762301          C&S WH llc      737074         2019.0
#
#          doc_id  posting_date  document_create_date  document_create_date.1  \
# 0  1.928543e+09        737058                737058                  737058
# 1  1.928543e+09        737058                737058                  737058
# 2  1.928541e+09        737058                737057                  737058
# 3  1.928538e+09        737058                737057                  737058
# 4  1.928540e+09        737058                737057                  737058
#
#    due_in_date invoice_currency document type  posting_id  total_open_amount  \
# 0       737073              USD            RV         1.0           94123.08
# 1       737073              USD            RV         1.0           45645.00
# 2       737073              USD            RV         1.0            8286.44
# 3       737073              USD            RV         1.0           51600.07
# 4       737073              USD            RV         1.0           13866.83
#
#    baseline_create_date cust_payment_terms    invoice_id  isOpen
# 0                737058               NAA8  1.928543e+09       0
# 1                737058               NAH4  1.928543e+09       0
# 2                737058               NAH4  1.928541e+09       0
# 3                737058               NAH4  1.928538e+09       0
# 4                737058               NAC6  1.928540e+09       0

# %%
df.dtypes #Variance Threshold only work on int/float
# Out:
# business_code              object
# cust_number                object
# name_customer              object
# clear_date                  int64
# buisness_year             float64
# doc_id                    float64
# posting_date                int64
# document_create_date        int64
# document_create_date.1      int64
# due_in_date                 int64
# invoice_currency           object
# document type              object
# posting_id                float64
# total_open_amount         float64
# baseline_create_date        int64
# cust_payment_terms         object
# invoice_id                float64
# isOpen                      int64
# dtype: object

# %%
#storing converted datatypes in temp dataframe
df_temp = df.select_dtypes(exclude=['object'])
df_temp.head()
# Out:
#    clear_date  buisness_year        doc_id  posting_date  \
# 0      737075         2019.0  1.928543e+09        737058
# 1      737070         2019.0  1.928543e+09        737058
# 2      737068         2019.0  1.928541e+09        737058
# 3      737068         2019.0  1.928538e+09        737058
# 4      737074         2019.0  1.928540e+09        737058
#
#    document_create_date  document_create_date.1  due_in_date  posting_id  \
# 0                737058                  737058       737073         1.0
# 1                737058                  737058       737073         1.0
# 2                737057                  737058       737073         1.0
# 3                737057                  737058       737073         1.0
# 4                737057                  737058       737073         1.0
#
#    total_open_amount  baseline_create_date    invoice_id  isOpen
# 0           94123.08                737058  1.928543e+09       0
# 1           45645.00                737058  1.928543e+09       0
# 2            8286.44                737058  1.928541e+09       0
# 3           51600.07                737058  1.928538e+09       0
# 4           13866.83                737058  1.928540e+09       0

# %%
var_thresh = VarianceThreshold(threshold=0)

# %%
var_thresh.fit(df_temp)
# Out:
# VarianceThreshold(threshold=0)

# %%
# The false value is a constant feature
var_thresh.get_support()
# Out:
# array([ True,  True,  True,  True,  True,  True,  True, False,  True,
#         True,  True, False])

# %%
df_temp.columns[var_thresh.get_support()] # non constant features
# Out:
# Index(['clear_date', 'buisness_year', 'doc_id', 'posting_date',
#        'document_create_date', 'document_create_date.1', 'due_in_date',
#        'total_open_amount', 'baseline_create_date', 'invoice_id'],
#       dtype='object')

# %%
# storing constant features
constant_columns = [column for column in df_temp.columns 
                   if column not in df_temp.columns[var_thresh.get_support()]]

# %%
# printing constant feature(s)
for features in constant_columns:
    print(features)
# Out:
# posting_id
# isOpen

# %%
# droping constant feature(s)
df.drop(constant_columns,axis=1,inplace=True)

# %%
df.head()
# Out:
#   business_code cust_number       name_customer  clear_date  buisness_year  \
# 0          U001  0200779906            BOZZU in      737075         2019.0
# 1          U001  0200769623        WAL-MAR corp      737070         2019.0
# 2          U001  0200769623  WAL-MAR foundation      737068         2019.0
# 3          U001  0200769623            WAL-MAR       737068         2019.0
# 4          U001  0200762301          C&S WH llc      737074         2019.0
#
#          doc_id  posting_date  document_create_date  document_create_date.1  \
# 0  1.928543e+09        737058                737058                  737058
# 1  1.928543e+09        737058                737058                  737058
# 2  1.928541e+09        737058                737057                  737058
# 3  1.928538e+09        737058                737057                  737058
# 4  1.928540e+09        737058                737057                  737058
#
#    due_in_date invoice_currency document type  total_open_amount  \
# 0       737073              USD            RV           94123.08
# 1       737073              USD            RV           45645.00
# 2       737073              USD            RV            8286.44
# 3       737073              USD            RV           51600.07
# 4       737073              USD            RV           13866.83
#
#    baseline_create_date cust_payment_terms    invoice_id
# 0                737058               NAA8  1.928543e+09
# 1                737058               NAH4  1.928543e+09
# 2                737058               NAH4  1.928541e+09
# 3                737058               NAH4  1.928538e+09
# 4                737058               NAC6  1.928540e+09

# %%
df.shape #Constant Feature removed
# Out:
# (39168, 16)

# %% [markdown]
# ## Removing Quasi-Constant Features

# %%
from sklearn.feature_selection import VarianceThreshold

# %%
# applying variance threshold
df.head()
# Out:
#   business_code cust_number       name_customer  clear_date  buisness_year  \
# 0          U001  0200779906            BOZZU in      737075         2019.0
# 1          U001  0200769623        WAL-MAR corp      737070         2019.0
# 2          U001  0200769623  WAL-MAR foundation      737068         2019.0
# 3          U001  0200769623            WAL-MAR       737068         2019.0
# 4          U001  0200762301          C&S WH llc      737074         2019.0
#
#          doc_id  posting_date  document_create_date  document_create_date.1  \
# 0  1.928543e+09        737058                737058                  737058
# 1  1.928543e+09        737058                737058                  737058
# 2  1.928541e+09        737058                737057                  737058
# 3  1.928538e+09        737058                737057                  737058
# 4  1.928540e+09        737058                737057                  737058
#
#    due_in_date invoice_currency document type  total_open_amount  \
# 0       737073              USD            RV           94123.08
# 1       737073              USD            RV           45645.00
# 2       737073              USD            RV            8286.44
# 3       737073              USD            RV           51600.07
# 4       737073              USD            RV           13866.83
#
#    baseline_create_date cust_payment_terms    invoice_id
# 0                737058               NAA8  1.928543e+09
# 1                737058               NAH4  1.928543e+09
# 2                737058               NAH4  1.928541e+09
# 3                737058               NAH4  1.928538e+09
# 4                737058               NAC6  1.928540e+09

# %%
df_temp = df.select_dtypes(exclude=['object'])
df_temp.head()
# Out:
#    clear_date  buisness_year        doc_id  posting_date  \
# 0      737075         2019.0  1.928543e+09        737058
# 1      737070         2019.0  1.928543e+09        737058
# 2      737068         2019.0  1.928541e+09        737058
# 3      737068         2019.0  1.928538e+09        737058
# 4      737074         2019.0  1.928540e+09        737058
#
#    document_create_date  document_create_date.1  due_in_date  \
# 0                737058                  737058       737073
# 1                737058                  737058       737073
# 2                737057                  737058       737073
# 3                737057                  737058       737073
# 4                737057                  737058       737073
#
#    total_open_amount  baseline_create_date    invoice_id
# 0           94123.08                737058  1.928543e+09
# 1           45645.00                737058  1.928543e+09
# 2            8286.44                737058  1.928541e+09
# 3           51600.07                737058  1.928538e+09
# 4           13866.83                737058  1.928540e+09

# %%
var_thresh = VarianceThreshold(threshold=0.3)

# %%
var_thresh.fit(df_temp)
# Out:
# VarianceThreshold(threshold=0.3)

# %%
var_thresh.get_support()
# Out:
# array([ True, False,  True,  True,  True,  True,  True,  True,  True,
#         True])

# %%
df_temp.columns[var_thresh.get_support()]
# Out:
# Index(['clear_date', 'doc_id', 'posting_date', 'document_create_date',
#        'document_create_date.1', 'due_in_date', 'total_open_amount',
#        'baseline_create_date', 'invoice_id'],
#       dtype='object')

# %%
# storing quasi constant features
quasi_columns = [column for column in df_temp.columns 
                   if column not in df_temp.columns[var_thresh.get_support()]]

# %%
# printing quasi constant feature(s)
for features in quasi_columns:
    print(features)
# Out:
# buisness_year

# %%
# droping quasi constant feature(s)
df.drop(quasi_columns,axis=1,inplace=True)

# %%
df.head()
# Out:
#   business_code cust_number       name_customer  clear_date        doc_id  \
# 0          U001  0200779906            BOZZU in      737075  1.928543e+09
# 1          U001  0200769623        WAL-MAR corp      737070  1.928543e+09
# 2          U001  0200769623  WAL-MAR foundation      737068  1.928541e+09
# 3          U001  0200769623            WAL-MAR       737068  1.928538e+09
# 4          U001  0200762301          C&S WH llc      737074  1.928540e+09
#
#    posting_date  document_create_date  document_create_date.1  due_in_date  \
# 0        737058                737058                  737058       737073
# 1        737058                737058                  737058       737073
# 2        737058                737057                  737058       737073
# 3        737058                737057                  737058       737073
# 4        737058                737057                  737058       737073
#
#   invoice_currency document type  total_open_amount  baseline_create_date  \
# 0              USD            RV           94123.08                737058
# 1              USD            RV           45645.00                737058
# 2              USD            RV            8286.44                737058
# 3              USD            RV           51600.07                737058
# 4              USD            RV           13866.83                737058
#
#   cust_payment_terms    invoice_id
# 0               NAA8  1.928543e+09
# 1               NAH4  1.928543e+09
# 2               NAH4  1.928541e+09
# 3               NAH4  1.928538e+09
# 4               NAC6  1.928540e+09

# %%
df.shape
# Out:
# (39168, 15)

# %% [markdown]
# ## Checking Unique Values with object datatype

# %%
# Checking for object data types
for col in df:
    if df[col].dtypes == object:
        print(col , ' : ', len(df[col].unique()))
# Out:
# business_code  :  6
# cust_number  :  1335
# name_customer  :  3887
# invoice_currency  :  2
# document type  :  1
# cust_payment_terms  :  69

# %% [markdown]
# ## Applying count of frequency encoding on business_code

# %%
df_frequency_map = df.business_code.value_counts().to_dict()

# %%
df.business_code = df.business_code.map(df_frequency_map)

# %%
df.head()
# Out:
#    business_code cust_number       name_customer  clear_date        doc_id  \
# 0          35450  0200779906            BOZZU in      737075  1.928543e+09
# 1          35450  0200769623        WAL-MAR corp      737070  1.928543e+09
# 2          35450  0200769623  WAL-MAR foundation      737068  1.928541e+09
# 3          35450  0200769623            WAL-MAR       737068  1.928538e+09
# 4          35450  0200762301          C&S WH llc      737074  1.928540e+09
#
#    posting_date  document_create_date  document_create_date.1  due_in_date  \
# 0        737058                737058                  737058       737073
# 1        737058                737058                  737058       737073
# 2        737058                737057                  737058       737073
# 3        737058                737057                  737058       737073
# 4        737058                737057                  737058       737073
#
#   invoice_currency document type  total_open_amount  baseline_create_date  \
# 0              USD            RV           94123.08                737058
# 1              USD            RV           45645.00                737058
# 2              USD            RV            8286.44                737058
# 3              USD            RV           51600.07                737058
# 4              USD            RV           13866.83                737058
#
#   cust_payment_terms    invoice_id
# 0               NAA8  1.928543e+09
# 1               NAH4  1.928543e+09
# 2               NAH4  1.928541e+09
# 3               NAH4  1.928538e+09
# 4               NAC6  1.928540e+09

# %% [markdown]
# ## Applying one hot encoding on invoice_currency

# %%
df_temp = pd.get_dummies(df['invoice_currency'],drop_first=True)

# %%
df = pd.concat([df_temp,df],axis=1)

# %%
df.drop('invoice_currency',axis=1,inplace=True)

# %%
df.head()
# Out:
#    USD  business_code cust_number       name_customer  clear_date  \
# 0    1          35450  0200779906            BOZZU in      737075
# 1    1          35450  0200769623        WAL-MAR corp      737070
# 2    1          35450  0200769623  WAL-MAR foundation      737068
# 3    1          35450  0200769623            WAL-MAR       737068
# 4    1          35450  0200762301          C&S WH llc      737074
#
#          doc_id  posting_date  document_create_date  document_create_date.1  \
# 0  1.928543e+09        737058                737058                  737058
# 1  1.928543e+09        737058                737058                  737058
# 2  1.928541e+09        737058                737057                  737058
# 3  1.928538e+09        737058                737057                  737058
# 4  1.928540e+09        737058                737057                  737058
#
#    due_in_date document type  total_open_amount  baseline_create_date  \
# 0       737073            RV           94123.08                737058
# 1       737073            RV           45645.00                737058
# 2       737073            RV            8286.44                737058
# 3       737073            RV           51600.07                737058
# 4       737073            RV           13866.83                737058
#
#   cust_payment_terms    invoice_id
# 0               NAA8  1.928543e+09
# 1               NAH4  1.928543e+09
# 2               NAH4  1.928541e+09
# 3               NAH4  1.928538e+09
# 4               NAC6  1.928540e+09

# %%
df.shape
# Out:
# (39168, 15)

# %% [markdown]
# ## Removing unwanted columns

# %%
df.head()
# Out:
#    USD  business_code cust_number       name_customer  clear_date  \
# 0    1          35450  0200779906            BOZZU in      737075
# 1    1          35450  0200769623        WAL-MAR corp      737070
# 2    1          35450  0200769623  WAL-MAR foundation      737068
# 3    1          35450  0200769623            WAL-MAR       737068
# 4    1          35450  0200762301          C&S WH llc      737074
#
#          doc_id  posting_date  document_create_date  document_create_date.1  \
# 0  1.928543e+09        737058                737058                  737058
# 1  1.928543e+09        737058                737058                  737058
# 2  1.928541e+09        737058                737057                  737058
# 3  1.928538e+09        737058                737057                  737058
# 4  1.928540e+09        737058                737057                  737058
#
#    due_in_date document type  total_open_amount  baseline_create_date  \
# 0       737073            RV           94123.08                737058
# 1       737073            RV           45645.00                737058
# 2       737073            RV            8286.44                737058
# 3       737073            RV           51600.07                737058
# 4       737073            RV           13866.83                737058
#
#   cust_payment_terms    invoice_id
# 0               NAA8  1.928543e+09
# 1               NAH4  1.928543e+09
# 2               NAH4  1.928541e+09
# 3               NAH4  1.928538e+09
# 4               NAC6  1.928540e+09

# %%
# all these columns contains unique id's or names which may work as outliers for our model
df.drop(['cust_number','name_customer','document type','document_create_date.1'] , axis = 1 , inplace = True)

# %%
df.shape
# Out:
# (39168, 11)

# %% [markdown]
# ## Creating Delay Column

# %%
df['clear_date'].dtype
# Out:
# dtype('int64')

# %%
df['delay'] = df['clear_date'] - df['due_in_date']

# %%
df.head()
# Out:
#    USD  business_code  clear_date        doc_id  posting_date  \
# 0    1          35450      737075  1.928543e+09        737058
# 1    1          35450      737070  1.928543e+09        737058
# 2    1          35450      737068  1.928541e+09        737058
# 3    1          35450      737068  1.928538e+09        737058
# 4    1          35450      737074  1.928540e+09        737058
#
#    document_create_date  due_in_date  total_open_amount  baseline_create_date  \
# 0                737058       737073           94123.08                737058
# 1                737058       737073           45645.00                737058
# 2                737057       737073            8286.44                737058
# 3                737057       737073           51600.07                737058
# 4                737057       737073           13866.83                737058
#
#   cust_payment_terms    invoice_id  delay
# 0               NAA8  1.928543e+09      2
# 1               NAH4  1.928543e+09     -3
# 2               NAH4  1.928541e+09     -5
# 3               NAH4  1.928538e+09     -5
# 4               NAC6  1.928540e+09      1

# %% [markdown]
# ## Applying count of frequency encoding on cust_payment_terms

# %%
df_frequency_map = df.cust_payment_terms.value_counts().to_dict()

# %%
df_frequency_map
# Out:
# {'NAA8': 15595,
#  'NAH4': 10699,
#  'CA10': 2979,
#  'NAC6': 1278,
#  'NAM4': 1026,
#  'NAAX': 932,
#  'NAG2': 743,
#  'NAD1': 727,
#  'NAU5': 719,
#  'NAGD': 622,
#  'NA32': 592,
#  'NAX2': 522,
#  'NAM2': 432,
#  'NA10': 352,
#  'NAD5': 256,
#  'NAVE': 235,
#  'NAM1': 216,
#  'NAVF': 195,
#  'NAAW': 173,
#  'NAWU': 123,
#  'NAWN': 91,
#  'NAVQ': 87,
#  'NAVR': 74,
#  'NAWP': 64,
#  'NAUZ': 50,
#  'CA30': 37,
#  'NA3B': 37,
#  'NAVM': 37,
#  'NABG': 29,
#  'NACB': 27,
#  'NA38': 26,
#  'NAD4': 20,
#  'C106': 20,
#  'NAB1': 18,
#  'NAVL': 12,
#  'NA25': 9,
#  'NAM3': 9,
#  'NAUP': 8,
#  'NA84': 8,
#  'NAVD': 7,
#  'NA3F': 6,
#  'CAB1': 6,
#  'BR56': 5,
#  'NAUI': 5,
#  'NAV2': 5,
#  'NATU': 4,
#  'NAD8': 4,
#  'NAV9': 4,
#  'NATX': 4,
#  'CAX2': 4,
#  'B052': 3,
#  'NATV': 3,
#  'NAVC': 3,
#  'NA8Q': 3,
#  'NA9X': 3,
#  'NA31': 2,
#  'NAUN': 2,
#  'NAWM': 2,
#  'BR12': 2,
#  'NANC': 2,
#  'NATK': 2,
#  'NATH': 1,
#  'NATW': 1,
#  '90M7': 1,
#  'BR60': 1,
#  'NAUY': 1,
#  'NACE': 1,
#  'NATM': 1,
#  'NATJ': 1}

# %%
df.cust_payment_terms = df.cust_payment_terms.map(df_frequency_map)

# %%
df.head()
# Out:
#    USD  business_code  clear_date        doc_id  posting_date  \
# 0    1          35450      737075  1.928543e+09        737058
# 1    1          35450      737070  1.928543e+09        737058
# 2    1          35450      737068  1.928541e+09        737058
# 3    1          35450      737068  1.928538e+09        737058
# 4    1          35450      737074  1.928540e+09        737058
#
#    document_create_date  due_in_date  total_open_amount  baseline_create_date  \
# 0                737058       737073           94123.08                737058
# 1                737058       737073           45645.00                737058
# 2                737057       737073            8286.44                737058
# 3                737057       737073           51600.07                737058
# 4                737057       737073           13866.83                737058
#
#    cust_payment_terms    invoice_id  delay
# 0               15595  1.928543e+09      2
# 1               10699  1.928543e+09     -3
# 2               10699  1.928541e+09     -5
# 3               10699  1.928538e+09     -5
# 4                1278  1.928540e+09      1

# %% [markdown]
# ## Data Visualisation

# %%
# total_open_amount vs due_in_date 
x = df['delay']
y = df['cust_payment_terms']
plt.scatter(x,y)
plt.xlabel("delay")
plt.ylabel("cust_payment_terms")
plt.title("delay vs cust_payment_terms")

#This shows us that customers with cust_payment_terms between 0 to 2000 made roughly 30% of their payment on time 
#and almost all customes paid their dues within 150 days
# Out:
# Text(0.5, 1.0, 'delay vs cust_payment_terms')

# %%
import seaborn as sns
sns.relplot(x="business_code", y="delay", sort=False, kind="line", data=df);
# This graph shows us that the delay decreased in an discending order of business_code

# %%
# total_open_amount vs due_in_date 
x = df['delay']
y = df['posting_date']
plt.scatter(x,y)
plt.xlabel("delay")
plt.ylabel("posting_date")
plt.title("delay vs posting_date")

#This also shows us the same trend that almost all customes paid their dues within 150 days
# Out:
# Text(0.5, 1.0, 'delay vs posting_date')

# %%
plt.figure(figsize=(6,6))
plt.figure(2)
sns.distplot(df['delay'],color='green')
# This graph is right skewed
# Out:
# <AxesSubplot:xlabel='delay', ylabel='Density'>

# %%
plt.figure(figsize=(8,8))
plt.figure(1)
sns.distplot(df['total_open_amount'],color='red')
# Out:
# <AxesSubplot:xlabel='total_open_amount', ylabel='Density'>

# %%
# This graph is again right skewed ; could be removed from the dataset if low accuracy encountered

# %% [markdown]
# ## Data preprocessing of Test_data

# %%
df.head()
# Out:
#    USD  business_code  clear_date        doc_id  posting_date  \
# 0    1          35450      737075  1.928543e+09        737058
# 1    1          35450      737070  1.928543e+09        737058
# 2    1          35450      737068  1.928541e+09        737058
# 3    1          35450      737068  1.928538e+09        737058
# 4    1          35450      737074  1.928540e+09        737058
#
#    document_create_date  due_in_date  total_open_amount  baseline_create_date  \
# 0                737058       737073           94123.08                737058
# 1                737058       737073           45645.00                737058
# 2                737057       737073            8286.44                737058
# 3                737057       737073           51600.07                737058
# 4                737057       737073           13866.83                737058
#
#    cust_payment_terms    invoice_id  delay
# 0               15595  1.928543e+09      2
# 1               10699  1.928543e+09     -3
# 2               10699  1.928541e+09     -5
# 3               10699  1.928538e+09     -5
# 4                1278  1.928540e+09      1

# %%
test_data.head()
# Out:
#    business_code cust_number      name_customer clear_date  buisness_year  \
# 14          U001  0200762301     C&S WH systems        NaN         2020.0
# 15          U001  0200762301  C&S WH associates        NaN         2020.0
# 22          U001  0200769623        WAL-MAR llc        NaN         2020.0
# 35          U001  0200799342           MITCH co        NaN         2020.0
# 54          U001  0200726979           BJ'S  us        NaN         2020.0
#
#           doc_id posting_date  document_create_date  document_create_date.1  \
# 14  1.930630e+09   2020-03-11              20200310                20200311
# 15  1.930733e+09   2020-04-02              20200402                20200402
# 22  1.930834e+09   2020-04-29              20200429                20200429
# 35  1.930643e+09   2020-03-12              20200312                20200312
# 54  1.930724e+09   2020-03-31              20200331                20200331
#
#     due_in_date invoice_currency document type  posting_id  area_business  \
# 14   20200326.0              USD            RV         1.0            NaN
# 15   20200417.0              USD            RV         1.0            NaN
# 22   20200514.0              USD            RV         1.0            NaN
# 35   20200327.0              USD            RV         1.0            NaN
# 54   20200415.0              USD            RV         1.0            NaN
#
#     total_open_amount  baseline_create_date cust_payment_terms    invoice_id  \
# 14           14169.42            20200311.0               NAC6  1.930630e+09
# 15           64394.42            20200402.0               NAC6  1.930733e+09
# 22           25333.15            20200429.0               NAH4  1.930834e+09
# 35            2183.30            20200312.0               NAA8  1.930643e+09
# 54             212.41            20200331.0               NAA8  1.930724e+09
#
#     isOpen
# 14       1
# 15       1
# 22       1
# 35       1
# 54       1

# %% [markdown]
# ### Applying one hot encoding on invoice_currency

# %%
df_temp = pd.get_dummies(test_data['invoice_currency'],drop_first=True)
test_data = pd.concat([df_temp,test_data],axis=1)
test_data.drop('invoice_currency',axis=1,inplace=True)

# %%
test_data.head()
# Out:
#     USD business_code cust_number      name_customer clear_date  \
# 14    1          U001  0200762301     C&S WH systems        NaN
# 15    1          U001  0200762301  C&S WH associates        NaN
# 22    1          U001  0200769623        WAL-MAR llc        NaN
# 35    1          U001  0200799342           MITCH co        NaN
# 54    1          U001  0200726979           BJ'S  us        NaN
#
#     buisness_year        doc_id posting_date  document_create_date  \
# 14         2020.0  1.930630e+09   2020-03-11              20200310
# 15         2020.0  1.930733e+09   2020-04-02              20200402
# 22         2020.0  1.930834e+09   2020-04-29              20200429
# 35         2020.0  1.930643e+09   2020-03-12              20200312
# 54         2020.0  1.930724e+09   2020-03-31              20200331
#
#     document_create_date.1  due_in_date document type  posting_id  \
# 14                20200311   20200326.0            RV         1.0
# 15                20200402   20200417.0            RV         1.0
# 22                20200429   20200514.0            RV         1.0
# 35                20200312   20200327.0            RV         1.0
# 54                20200331   20200415.0            RV         1.0
#
#     area_business  total_open_amount  baseline_create_date cust_payment_terms  \
# 14            NaN           14169.42            20200311.0               NAC6
# 15            NaN           64394.42            20200402.0               NAC6
# 22            NaN           25333.15            20200429.0               NAH4
# 35            NaN            2183.30            20200312.0               NAA8
# 54            NaN             212.41            20200331.0               NAA8
#
#       invoice_id  isOpen
# 14  1.930630e+09       1
# 15  1.930733e+09       1
# 22  1.930834e+09       1
# 35  1.930643e+09       1
# 54  1.930724e+09       1

# %% [markdown]
# ### Applying count pf frequency encoding on business_code

# %%
df_frequency_map = test_data.business_code.value_counts().to_dict()
test_data.business_code = test_data.business_code.map(df_frequency_map)

# %%
test_data.head()
# Out:
#     USD  business_code cust_number      name_customer clear_date  \
# 14    1           9179  0200762301     C&S WH systems        NaN
# 15    1           9179  0200762301  C&S WH associates        NaN
# 22    1           9179  0200769623        WAL-MAR llc        NaN
# 35    1           9179  0200799342           MITCH co        NaN
# 54    1           9179  0200726979           BJ'S  us        NaN
#
#     buisness_year        doc_id posting_date  document_create_date  \
# 14         2020.0  1.930630e+09   2020-03-11              20200310
# 15         2020.0  1.930733e+09   2020-04-02              20200402
# 22         2020.0  1.930834e+09   2020-04-29              20200429
# 35         2020.0  1.930643e+09   2020-03-12              20200312
# 54         2020.0  1.930724e+09   2020-03-31              20200331
#
#     document_create_date.1  due_in_date document type  posting_id  \
# 14                20200311   20200326.0            RV         1.0
# 15                20200402   20200417.0            RV         1.0
# 22                20200429   20200514.0            RV         1.0
# 35                20200312   20200327.0            RV         1.0
# 54                20200331   20200415.0            RV         1.0
#
#     area_business  total_open_amount  baseline_create_date cust_payment_terms  \
# 14            NaN           14169.42            20200311.0               NAC6
# 15            NaN           64394.42            20200402.0               NAC6
# 22            NaN           25333.15            20200429.0               NAH4
# 35            NaN            2183.30            20200312.0               NAA8
# 54            NaN             212.41            20200331.0               NAA8
#
#       invoice_id  isOpen
# 14  1.930630e+09       1
# 15  1.930733e+09       1
# 22  1.930834e+09       1
# 35  1.930643e+09       1
# 54  1.930724e+09       1

# %%
df.head()
# Out:
#    USD  business_code  clear_date        doc_id  posting_date  \
# 0    1          35450      737075  1.928543e+09        737058
# 1    1          35450      737070  1.928543e+09        737058
# 2    1          35450      737068  1.928541e+09        737058
# 3    1          35450      737068  1.928538e+09        737058
# 4    1          35450      737074  1.928540e+09        737058
#
#    document_create_date  due_in_date  total_open_amount  baseline_create_date  \
# 0                737058       737073           94123.08                737058
# 1                737058       737073           45645.00                737058
# 2                737057       737073            8286.44                737058
# 3                737057       737073           51600.07                737058
# 4                737057       737073           13866.83                737058
#
#    cust_payment_terms    invoice_id  delay
# 0               15595  1.928543e+09      2
# 1               10699  1.928543e+09     -3
# 2               10699  1.928541e+09     -5
# 3               10699  1.928538e+09     -5
# 4                1278  1.928540e+09      1

# %% [markdown]
# ### Converting all dates to date format

# %%
test_data['clear_date'] = pd.to_datetime(test_data.clear_date)
test_data['posting_date'] = pd.to_datetime(test_data.posting_date)
test_data.head()

test_data['document_create_date'] = pd.to_datetime(test_data['document_create_date'], format='%Y%m%d')
test_data['document_create_date.1'] = pd.to_datetime(test_data['document_create_date.1'], format='%Y%m%d')

test_data['due_in_date'] = test_data['due_in_date'].astype(int)
test_data['baseline_create_date'] = test_data['baseline_create_date'].astype(int)

test_data['due_in_date'] = pd.to_datetime(test_data['due_in_date'], format='%Y%m%d')
test_data['baseline_create_date'] = pd.to_datetime(test_data['baseline_create_date'], format='%Y%m%d')
test_data.head()
# Out:
#     USD  business_code cust_number      name_customer clear_date  \
# 14    1           9179  0200762301     C&S WH systems        NaT
# 15    1           9179  0200762301  C&S WH associates        NaT
# 22    1           9179  0200769623        WAL-MAR llc        NaT
# 35    1           9179  0200799342           MITCH co        NaT
# 54    1           9179  0200726979           BJ'S  us        NaT
#
#     buisness_year        doc_id posting_date document_create_date  \
# 14         2020.0  1.930630e+09   2020-03-11           2020-03-10
# 15         2020.0  1.930733e+09   2020-04-02           2020-04-02
# 22         2020.0  1.930834e+09   2020-04-29           2020-04-29
# 35         2020.0  1.930643e+09   2020-03-12           2020-03-12
# 54         2020.0  1.930724e+09   2020-03-31           2020-03-31
#
#    document_create_date.1 due_in_date document type  posting_id  \
# 14             2020-03-11  2020-03-26            RV         1.0
# 15             2020-04-02  2020-04-17            RV         1.0
# 22             2020-04-29  2020-05-14            RV         1.0
# 35             2020-03-12  2020-03-27            RV         1.0
# 54             2020-03-31  2020-04-15            RV         1.0
#
#     area_business  total_open_amount baseline_create_date cust_payment_terms  \
# 14            NaN           14169.42           2020-03-11               NAC6
# 15            NaN           64394.42           2020-04-02               NAC6
# 22            NaN           25333.15           2020-04-29               NAH4
# 35            NaN            2183.30           2020-03-12               NAA8
# 54            NaN             212.41           2020-03-31               NAA8
#
#       invoice_id  isOpen
# 14  1.930630e+09       1
# 15  1.930733e+09       1
# 22  1.930834e+09       1
# 35  1.930643e+09       1
# 54  1.930724e+09       1

# %%
test_data['clear_date']=test_data['clear_date'].map(dt.datetime.toordinal)
test_data['posting_date']=test_data['posting_date'].map(dt.datetime.toordinal)
test_data['document_create_date']=test_data['document_create_date'].map(dt.datetime.toordinal)
test_data['document_create_date.1']=test_data['document_create_date.1'].map(dt.datetime.toordinal)
test_data['due_in_date']=test_data['due_in_date'].map(dt.datetime.toordinal)
test_data['baseline_create_date']=test_data['baseline_create_date'].map(dt.datetime.toordinal)

# %%
test_data.head()
# Out:
#     USD  business_code cust_number      name_customer  clear_date  \
# 14    1           9179  0200762301     C&S WH systems           1
# 15    1           9179  0200762301  C&S WH associates           1
# 22    1           9179  0200769623        WAL-MAR llc           1
# 35    1           9179  0200799342           MITCH co           1
# 54    1           9179  0200726979           BJ'S  us           1
#
#     buisness_year        doc_id  posting_date  document_create_date  \
# 14         2020.0  1.930630e+09        737495                737494
# 15         2020.0  1.930733e+09        737517                737517
# 22         2020.0  1.930834e+09        737544                737544
# 35         2020.0  1.930643e+09        737496                737496
# 54         2020.0  1.930724e+09        737515                737515
#
#     document_create_date.1  due_in_date document type  posting_id  \
# 14                  737495       737510            RV         1.0
# 15                  737517       737532            RV         1.0
# 22                  737544       737559            RV         1.0
# 35                  737496       737511            RV         1.0
# 54                  737515       737530            RV         1.0
#
#     area_business  total_open_amount  baseline_create_date cust_payment_terms  \
# 14            NaN           14169.42                737495               NAC6
# 15            NaN           64394.42                737517               NAC6
# 22            NaN           25333.15                737544               NAH4
# 35            NaN            2183.30                737496               NAA8
# 54            NaN             212.41                737515               NAA8
#
#       invoice_id  isOpen
# 14  1.930630e+09       1
# 15  1.930733e+09       1
# 22  1.930834e+09       1
# 35  1.930643e+09       1
# 54  1.930724e+09       1

# %%
df.head()
# Out:
#    USD  business_code  clear_date        doc_id  posting_date  \
# 0    1          35450      737075  1.928543e+09        737058
# 1    1          35450      737070  1.928543e+09        737058
# 2    1          35450      737068  1.928541e+09        737058
# 3    1          35450      737068  1.928538e+09        737058
# 4    1          35450      737074  1.928540e+09        737058
#
#    document_create_date  due_in_date  total_open_amount  baseline_create_date  \
# 0                737058       737073           94123.08                737058
# 1                737058       737073           45645.00                737058
# 2                737057       737073            8286.44                737058
# 3                737057       737073           51600.07                737058
# 4                737057       737073           13866.83                737058
#
#    cust_payment_terms    invoice_id  delay
# 0               15595  1.928543e+09      2
# 1               10699  1.928543e+09     -3
# 2               10699  1.928541e+09     -5
# 3               10699  1.928538e+09     -5
# 4                1278  1.928540e+09      1

# %% [markdown]
# ### Droping all unncessary columns that are not present in train dataset

# %%
test_data.drop(columns=['cust_number','name_customer','buisness_year','document_create_date.1','document type','posting_id','area_business','isOpen'],inplace=True)

# %% [markdown]
# ### Applying Count of frequency encoding cust_payment_terms

# %%
df_frequency_map = test_data.cust_payment_terms.value_counts().to_dict()
test_data.cust_payment_terms = test_data.cust_payment_terms.map(df_frequency_map)

# %%
test_data.head()
# Out:
#     USD  business_code  clear_date        doc_id  posting_date  \
# 14    1           9179           1  1.930630e+09        737495
# 15    1           9179           1  1.930733e+09        737517
# 22    1           9179           1  1.930834e+09        737544
# 35    1           9179           1  1.930643e+09        737496
# 54    1           9179           1  1.930724e+09        737515
#
#     document_create_date  due_in_date  total_open_amount  \
# 14                737494       737510           14169.42
# 15                737517       737532           64394.42
# 22                737544       737559           25333.15
# 35                737496       737511            2183.30
# 54                737515       737530             212.41
#
#     baseline_create_date  cust_payment_terms    invoice_id
# 14                737495                 405  1.930630e+09
# 15                737517                 405  1.930733e+09
# 22                737544                3025  1.930834e+09
# 35                737496                4035  1.930643e+09
# 54                737515                4035  1.930724e+09

# %%
df.head()
# Out:
#    USD  business_code  clear_date        doc_id  posting_date  \
# 0    1          35450      737075  1.928543e+09        737058
# 1    1          35450      737070  1.928543e+09        737058
# 2    1          35450      737068  1.928541e+09        737058
# 3    1          35450      737068  1.928538e+09        737058
# 4    1          35450      737074  1.928540e+09        737058
#
#    document_create_date  due_in_date  total_open_amount  baseline_create_date  \
# 0                737058       737073           94123.08                737058
# 1                737058       737073           45645.00                737058
# 2                737057       737073            8286.44                737058
# 3                737057       737073           51600.07                737058
# 4                737057       737073           13866.83                737058
#
#    cust_payment_terms    invoice_id  delay
# 0               15595  1.928543e+09      2
# 1               10699  1.928543e+09     -3
# 2               10699  1.928541e+09     -5
# 3               10699  1.928538e+09     -5
# 4                1278  1.928540e+09      1

# %% [markdown]
# ### Removing null values and duplicate values

# %%
# removing null values

test_data.isnull().sum()  #print no. of duplicated values
# Out:
# USD                     0
# business_code           0
# clear_date              0
# doc_id                  0
# posting_date            0
# document_create_date    0
# due_in_date             0
# total_open_amount       0
# baseline_create_date    0
# cust_payment_terms      0
# invoice_id              0
# dtype: int64

# %%
test_data.isnull().mean() #no null values found
# Out:
# USD                     0.0
# business_code           0.0
# clear_date              0.0
# doc_id                  0.0
# posting_date            0.0
# document_create_date    0.0
# due_in_date             0.0
# total_open_amount       0.0
# baseline_create_date    0.0
# cust_payment_terms      0.0
# invoice_id              0.0
# dtype: float64

# %%
# Removing duplicates from rows
test_data.duplicated().sum() #print no. of duplicated values
# Out:
# 356

# %%
test_data.loc[test_data.duplicated(),:]  # printing duplicates
# Out:
#        USD  business_code  clear_date        doc_id  posting_date  \
# 2212     1           9179           1  1.930694e+09        737509
# 4068     0            737           1  2.960628e+09        737528
# 4168     1           9179           1  1.930710e+09        737511
# 4954     1           9179           1  1.930689e+09        737507
# 5364     1           9179           1  1.930625e+09        737495
# ...    ...            ...         ...           ...           ...
# 49700    1           9179           1  1.930721e+09        737515
# 49752    1           9179           1  1.930666e+09        737503
# 49873    1           9179           1  1.930768e+09        737524
# 49885    1           9179           1  1.930717e+09        737514
# 49932    1           9179           1  1.930599e+09        737490
#
#        document_create_date  due_in_date  total_open_amount  \
# 2212                 737508       737524            1898.20
# 4068                 737528       737539           90196.38
# 4168                 737511       737526            1151.93
# 4954                 737507       737522             720.26
# 5364                 737493       737510           39133.77
# ...                     ...          ...                ...
# 49700                737514       737530           17753.69
# 49752                737502       737518           39895.05
# 49873                737524       737526            1104.53
# 49885                737513       737529           12518.32
# 49932                737488       737505           34155.12
#
#        baseline_create_date  cust_payment_terms    invoice_id
# 2212                 737509                3025  1.930694e+09
# 4068                 737529                 732  2.960628e+09
# 4168                 737511                4035  1.930710e+09
# 4954                 737507                4035  1.930689e+09
# 5364                 737495                3025  1.930625e+09
# ...                     ...                 ...           ...
# 49700                737515                3025  1.930721e+09
# 49752                737503                3025  1.930666e+09
# 49873                737516                 106  1.930768e+09
# 49885                737514                3025  1.930717e+09
# 49932                737490                3025  1.930599e+09
#
# [356 rows x 11 columns]

# %%
test_data.drop_duplicates(keep='first',inplace=True)

# %%
test_data.shape
# Out:
# (9644, 11)

# %%
# Removing duplicates from columns

# %%
# As the drop_duplicates work only on row therefore we will take transpose to convert columns to rows
transposed = test_data.T

# %%
transposed[transposed.duplicated(keep="first")]
# Out:
#                    14            15            22            35     \
# invoice_id  1.930630e+09  1.930733e+09  1.930834e+09  1.930643e+09
#
#                    54            56            62            63     \
# invoice_id  1.930724e+09  1.930787e+09  1.930706e+09  1.930679e+09
#
#                    64            79     ...         49949         49953  \
# invoice_id  1.930690e+09  1.930831e+09  ...  1.930621e+09  1.930582e+09
#
#                    49963         49967         49984         49987  \
# invoice_id  1.930802e+09  1.930595e+09  1.930817e+09  1.930809e+09
#
#                    49996         49997         49998         49999
# invoice_id  1.930630e+09  1.930660e+09  1.930795e+09  2.960618e+09
#
# [1 rows x 9644 columns]

# %%
test_data = transposed.T.infer_objects()

# %%
test_data.dtypes
# Out:
# USD                     float64
# business_code           float64
# clear_date              float64
# doc_id                  float64
# posting_date            float64
# document_create_date    float64
# due_in_date             float64
# total_open_amount       float64
# baseline_create_date    float64
# cust_payment_terms      float64
# invoice_id              float64
# dtype: object

# %%
test_data.shape
# Out:
# (9644, 11)

# %%
df.dtypes
# Out:
# USD                       uint8
# business_code             int64
# clear_date                int64
# doc_id                  float64
# posting_date              int64
# document_create_date      int64
# due_in_date               int64
# total_open_amount       float64
# baseline_create_date      int64
# cust_payment_terms        int64
# invoice_id              float64
# delay                     int64
# dtype: object

# %% [markdown]
# ## Feature selection by Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
X = df[['business_code', 'posting_date', 'document_create_date',
       'due_in_date', 'USD', 'total_open_amount',
       'baseline_create_date', 'cust_payment_terms' ]] # taking all the required features

# %%
Y = df['clear_date']

# %%
random_forest_model = RandomForestClassifier(n_estimators=20,random_state=11)

# %%
n_estimators = 25

# %%
random_state = 20

# %%
random_forest_model.fit(X,Y)
# Out:
# RandomForestClassifier(n_estimators=20, random_state=11)

# %%
features_importance_number = random_forest_model.feature_importances_

# %%
features_importance_number # importance of each feature
# Out:
# array([0.00741378, 0.09503983, 0.15236001, 0.12053549, 0.00413732,
#        0.39374682, 0.10707328, 0.11969347])

# %%
df.columns
# Out:
# Index(['USD', 'business_code', 'clear_date', 'doc_id', 'posting_date',
#        'document_create_date', 'due_in_date', 'total_open_amount',
#        'baseline_create_date', 'cust_payment_terms', 'invoice_id', 'delay'],
#       dtype='object')

# %%
df.corr()
# Out:
#                            USD  business_code  clear_date    doc_id  \
# USD                   1.000000       0.885946   -0.005314 -0.999598
# business_code         0.885946       1.000000   -0.013509 -0.898566
# clear_date           -0.005314      -0.013509    1.000000  0.007738
# doc_id               -0.999598      -0.898566    0.007738  1.000000
# posting_date         -0.000990       0.003645    0.993833  0.002617
# document_create_date -0.003184       0.002351    0.993675  0.004771
# due_in_date           0.007594       0.001384    0.996001 -0.005371
# total_open_amount    -0.182936      -0.152579    0.015926  0.182355
# baseline_create_date -0.008852      -0.003464    0.993903  0.010484
# cust_payment_terms    0.312250       0.372592   -0.030470 -0.317914
# invoice_id           -0.999598      -0.898566    0.007738  1.000000
# delay                -0.144339      -0.166432    0.032488  0.146547
#
#                       posting_date  document_create_date  due_in_date  \
# USD                      -0.000990             -0.003184     0.007594
# business_code             0.003645              0.002351     0.001384
# clear_date                0.993833              0.993675     0.996001
# doc_id                    0.002617              0.004771    -0.005371
# posting_date              1.000000              0.999920     0.996116
# document_create_date      0.999920              1.000000     0.995966
# due_in_date               0.996116              0.995966     1.000000
# total_open_amount         0.021047              0.022288     0.015109
# baseline_create_date      0.999745              0.999664     0.996221
# cust_payment_terms        0.002965              0.002492    -0.024907
# invoice_id                0.002617              0.004771    -0.005371
# delay                    -0.037707             -0.037801    -0.056939
#
#                       total_open_amount  baseline_create_date  \
# USD                           -0.182936             -0.008852
# business_code                 -0.152579             -0.003464
# clear_date                     0.015926              0.993903
# doc_id                         0.182355              0.010484
# posting_date                   0.021047              0.999745
# document_create_date           0.022288              0.999664
# due_in_date                    0.015109              0.996221
# total_open_amount              1.000000              0.023764
# baseline_create_date           0.023764              1.000000
# cust_payment_terms             0.045947              0.003854
# invoice_id                     0.182355              0.010484
# delay                          0.008940             -0.038114
#
#                       cust_payment_terms  invoice_id     delay
# USD                             0.312250   -0.999598 -0.144339
# business_code                   0.372592   -0.898566 -0.166432
# clear_date                     -0.030470    0.007738  0.032488
# doc_id                         -0.317914    1.000000  0.146547
# posting_date                    0.002965    0.002617 -0.037707
# document_create_date            0.002492    0.004771 -0.037801
# due_in_date                    -0.024907   -0.005371 -0.056939
# total_open_amount               0.045947    0.182355  0.008940
# baseline_create_date            0.003854    0.010484 -0.038114
# cust_payment_terms              1.000000   -0.317914 -0.061855
# invoice_id                     -0.317914    1.000000  0.146547
# delay                          -0.061855    0.146547  1.000000

# %% [markdown]
# ## Training model

# %% [markdown]
# ### Testing using the coulmns shown by the random forest classifier on the initial test (LINEAR REGRESSION)

# %%
X = df.drop(['clear_date', 'delay' ,'USD' , 'business_code', 'document_create_date'],axis = 1)
X.head()
# Out:
#          doc_id  posting_date  due_in_date  total_open_amount  \
# 0  1.928543e+09        737058       737073           94123.08
# 1  1.928543e+09        737058       737073           45645.00
# 2  1.928541e+09        737058       737073            8286.44
# 3  1.928538e+09        737058       737073           51600.07
# 4  1.928540e+09        737058       737073           13866.83
#
#    baseline_create_date  cust_payment_terms    invoice_id
# 0                737058               15595  1.928543e+09
# 1                737058               10699  1.928543e+09
# 2                737058               10699  1.928541e+09
# 3                737058               10699  1.928538e+09
# 4                737058                1278  1.928540e+09

# %%
y = df['delay']
y.head()
# Out:
# 0    2
# 1   -3
# 2   -5
# 3   -5
# 4    1
# Name: delay, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=10)

# %%
from sklearn.linear_model import LinearRegression
lr_clf = LinearRegression()
lr_clf.fit(X_train,y_train)
lr_clf.score(X_test,y_test) # accuracy
# Out:
# 0.08025052811266364

# %%
test_data.head()
# Out:
#     USD  business_code  clear_date        doc_id  posting_date  \
# 14  1.0         9179.0         1.0  1.930630e+09      737495.0
# 15  1.0         9179.0         1.0  1.930733e+09      737517.0
# 22  1.0         9179.0         1.0  1.930834e+09      737544.0
# 35  1.0         9179.0         1.0  1.930643e+09      737496.0
# 54  1.0         9179.0         1.0  1.930724e+09      737515.0
#
#     document_create_date  due_in_date  total_open_amount  \
# 14              737494.0     737510.0           14169.42
# 15              737517.0     737532.0           64394.42
# 22              737544.0     737559.0           25333.15
# 35              737496.0     737511.0            2183.30
# 54              737515.0     737530.0             212.41
#
#     baseline_create_date  cust_payment_terms    invoice_id
# 14              737495.0               405.0  1.930630e+09
# 15              737517.0               405.0  1.930733e+09
# 22              737544.0              3025.0  1.930834e+09
# 35              737496.0              4035.0  1.930643e+09
# 54              737515.0              4035.0  1.930724e+09

# %% [markdown]
# ### Testing using all the columns on initial test (LINEAR REGRESSION)

# %%
from sklearn import datasets, linear_model, metrics
from sklearn.model_selection import train_test_split

# %%
X = df.drop(['delay','clear_date'],axis = 1)
X.head()
# Out:
#    USD  business_code        doc_id  posting_date  document_create_date  \
# 0    1          35450  1.928543e+09        737058                737058
# 1    1          35450  1.928543e+09        737058                737058
# 2    1          35450  1.928541e+09        737058                737057
# 3    1          35450  1.928538e+09        737058                737057
# 4    1          35450  1.928540e+09        737058                737057
#
#    due_in_date  total_open_amount  baseline_create_date  cust_payment_terms  \
# 0       737073           94123.08                737058               15595
# 1       737073           45645.00                737058               10699
# 2       737073            8286.44                737058               10699
# 3       737073           51600.07                737058               10699
# 4       737073           13866.83                737058                1278
#
#      invoice_id
# 0  1.928543e+09
# 1  1.928543e+09
# 2  1.928541e+09
# 3  1.928538e+09
# 4  1.928540e+09

# %%
y = df['delay']
y.head()
# Out:
# 0    2
# 1   -3
# 2   -5
# 3   -5
# 4    1
# Name: delay, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=10)

# %%
from sklearn.linear_model import LinearRegression
lr_clf = LinearRegression()
lr_clf.fit(X_train,y_train)
lr_clf.score(X_test,y_test) # accuracy on initial test
# Out:
# 0.09674496430081003

# %% [markdown]
# ### Now using Random forest Model on initial test

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
random_forest_model = RandomForestRegressor()

# %%
random_forest_model.fit(X_train , y_train)
# Out:
# RandomForestRegressor()

# %%
random_forest_model.score(X_test,y_test)  #Accuracy increased (Best Model)
# Out:
# 0.3930610016985786

# %% [markdown]
# ### Prediction on final test

# %%
test_data.head()
# Out:
#     USD  business_code  clear_date        doc_id  posting_date  \
# 14  1.0         9179.0         1.0  1.930630e+09      737495.0
# 15  1.0         9179.0         1.0  1.930733e+09      737517.0
# 22  1.0         9179.0         1.0  1.930834e+09      737544.0
# 35  1.0         9179.0         1.0  1.930643e+09      737496.0
# 54  1.0         9179.0         1.0  1.930724e+09      737515.0
#
#     document_create_date  due_in_date  total_open_amount  \
# 14              737494.0     737510.0           14169.42
# 15              737517.0     737532.0           64394.42
# 22              737544.0     737559.0           25333.15
# 35              737496.0     737511.0            2183.30
# 54              737515.0     737530.0             212.41
#
#     baseline_create_date  cust_payment_terms    invoice_id
# 14              737495.0               405.0  1.930630e+09
# 15              737517.0               405.0  1.930733e+09
# 22              737544.0              3025.0  1.930834e+09
# 35              737496.0              4035.0  1.930643e+09
# 54              737515.0              4035.0  1.930724e+09

# %%
test_data.drop(['clear_date'],axis=1,inplace=True)

test_data['delay'] = random_forest_model.predict(test_data) # this is the predicted delay

# %%
test_data.head()
# Out:
#     USD  business_code        doc_id  posting_date  document_create_date  \
# 14  1.0         9179.0  1.930630e+09      737495.0              737494.0
# 15  1.0         9179.0  1.930733e+09      737517.0              737517.0
# 22  1.0         9179.0  1.930834e+09      737544.0              737544.0
# 35  1.0         9179.0  1.930643e+09      737496.0              737496.0
# 54  1.0         9179.0  1.930724e+09      737515.0              737515.0
#
#     due_in_date  total_open_amount  baseline_create_date  cust_payment_terms  \
# 14     737510.0           14169.42              737495.0               405.0
# 15     737532.0           64394.42              737517.0               405.0
# 22     737559.0           25333.15              737544.0              3025.0
# 35     737511.0            2183.30              737496.0              4035.0
# 54     737530.0             212.41              737515.0              4035.0
#
#       invoice_id  delay
# 14  1.930630e+09   2.06
# 15  1.930733e+09   3.88
# 22  1.930834e+09   0.41
# 35  1.930643e+09  10.38
# 54  1.930724e+09   3.40

# %%
test_data['delay'] = test_data.delay.astype(int)

# %%
test_data.head()
# Out:
#     USD  business_code        doc_id  posting_date  document_create_date  \
# 14  1.0         9179.0  1.930630e+09      737495.0              737494.0
# 15  1.0         9179.0  1.930733e+09      737517.0              737517.0
# 22  1.0         9179.0  1.930834e+09      737544.0              737544.0
# 35  1.0         9179.0  1.930643e+09      737496.0              737496.0
# 54  1.0         9179.0  1.930724e+09      737515.0              737515.0
#
#     due_in_date  total_open_amount  baseline_create_date  cust_payment_terms  \
# 14     737510.0           14169.42              737495.0               405.0
# 15     737532.0           64394.42              737517.0               405.0
# 22     737559.0           25333.15              737544.0              3025.0
# 35     737511.0            2183.30              737496.0              4035.0
# 54     737530.0             212.41              737515.0              4035.0
#
#       invoice_id  delay
# 14  1.930630e+09      2
# 15  1.930733e+09      3
# 22  1.930834e+09      0
# 35  1.930643e+09     10
# 54  1.930724e+09      3

# %% [markdown]
# ## Creating Clear date Column in test_data

# %%
test_data['predicted_clear_date'] = test_data['delay'] + test_data['due_in_date']

# %%
test_data.head()
# Out:
#     USD  business_code        doc_id  posting_date  document_create_date  \
# 14  1.0         9179.0  1.930630e+09      737495.0              737494.0
# 15  1.0         9179.0  1.930733e+09      737517.0              737517.0
# 22  1.0         9179.0  1.930834e+09      737544.0              737544.0
# 35  1.0         9179.0  1.930643e+09      737496.0              737496.0
# 54  1.0         9179.0  1.930724e+09      737515.0              737515.0
#
#     due_in_date  total_open_amount  baseline_create_date  cust_payment_terms  \
# 14     737510.0           14169.42              737495.0               405.0
# 15     737532.0           64394.42              737517.0               405.0
# 22     737559.0           25333.15              737544.0              3025.0
# 35     737511.0            2183.30              737496.0              4035.0
# 54     737530.0             212.41              737515.0              4035.0
#
#       invoice_id  delay  predicted_clear_date
# 14  1.930630e+09      2              737512.0
# 15  1.930733e+09      3              737535.0
# 22  1.930834e+09      0              737559.0
# 35  1.930643e+09     10              737521.0
# 54  1.930724e+09      3              737533.0

# %% [markdown]
# ### Segregating values according to Bucket

# %%
def seg_val_bucket(x):
    t = []
    for i in list(x):
        if i<=0:
            t.append("(<=0) Days")
        elif (i> 0 and i<16):
            t.append("(0-15) Days")
        elif (i >= 16 and i<31): 
            t.append("(16-30) Days")
        elif (i >= 31 and i<46):
            t.append("(31-45) Days")
        elif (i >= 46 and i<61):
            t.append("(46-60) Days")
        else:
            t.append("(> 60) Days")
    return t

# 1)0-15 days
# 2)16-30 days
# 3)31-45 days
# 4)46-60 days
# 5) greater than 60 days

# %%
bucket_vals = seg_val_bucket(test_data['delay'])

# %%
test_data['bucket_vals'] = bucket_vals # creating new column for containing bucket values

# %%
test_data.head()
# Out:
#     USD  business_code        doc_id  posting_date  document_create_date  \
# 14  1.0         9179.0  1.930630e+09      737495.0              737494.0
# 15  1.0         9179.0  1.930733e+09      737517.0              737517.0
# 22  1.0         9179.0  1.930834e+09      737544.0              737544.0
# 35  1.0         9179.0  1.930643e+09      737496.0              737496.0
# 54  1.0         9179.0  1.930724e+09      737515.0              737515.0
#
#     due_in_date  total_open_amount  baseline_create_date  cust_payment_terms  \
# 14     737510.0           14169.42              737495.0               405.0
# 15     737532.0           64394.42              737517.0               405.0
# 22     737559.0           25333.15              737544.0              3025.0
# 35     737511.0            2183.30              737496.0              4035.0
# 54     737530.0             212.41              737515.0              4035.0
#
#       invoice_id  delay  predicted_clear_date  bucket_vals
# 14  1.930630e+09      2              737512.0  (0-15) Days
# 15  1.930733e+09      3              737535.0  (0-15) Days
# 22  1.930834e+09      0              737559.0   (<=0) Days
# 35  1.930643e+09     10              737521.0  (0-15) Days
# 54  1.930724e+09      3              737533.0  (0-15) Days

# %%
import seaborn as sns
sns.countplot(x = 'bucket_vals',data = test_data) # count ploting bucket values
# Out:
# <AxesSubplot:xlabel='bucket_vals', ylabel='count'>

# %%
test_data['bucket_vals'].value_counts() #frequency of bucket values
# Out:
# (0-15) Days     5305
# (<=0) Days      4200
# (16-30) Days     133
# (46-60) Days       5
# (31-45) Days       1
# Name: bucket_vals, dtype: int64

# %% [markdown]
# ## Feature Scaling

# %%
# X_train = test_data.drop(['clear_date' , 'delay' , 'bucket_vals'],axis = 1)
# y_train = test_data['delay']
# X_val = test_data.drop(['clear_date' , 'delay' , 'bucket_vals'],axis = 1)
# y_val = d_val['delay']

# %%
# from sklearn.preprocessing import StandardScaler
# scaler = StandardScaler()

# %%
# X_train = pd.DataFrame(scaler.fit_transform(X_train), index=X_train.index, columns=X_train.columns)
# X_train.head()

# %%
# X_val = pd.DataFrame(scaler.fit_transform(X_val), index=X_val.index, columns=X_val.columns)
# X_val.head()

# %%
# Not performing feature scaling as it is reducing the accuracy drastically

# %% [markdown]
# ### Calculating Root mean square and mean square

# %%
# Root mean square and mean error square for linear regression
y_predict = lr_clf.predict(X_test)

from sklearn import metrics
print('Mean Squared error : ',metrics.mean_squared_error(y_test, y_predict, squared=False))
print('Root Mean Squared error : ',np.sqrt(metrics.mean_squared_error(y_test, y_predict, squared=False)))
# Out:
# Mean Squared error :  10.401465879695717
# Root Mean Squared error :  3.2251303663101307

# %%
# Root mean square and mean square error for Random forest Model 
y_predict = random_forest_model.predict(X_test)

from sklearn import metrics
print('Mean Squared error : ',metrics.mean_squared_error(y_test, y_predict, squared=False))
print('Root Mean Squared error : ',np.sqrt(metrics.mean_squared_error(y_test, y_predict, squared=False)))
# Out:
# Mean Squared error :  8.526324844916282
# Root Mean Squared error :  2.919987130950457

# %% [markdown]
# ## Converting dates from ordinal format to time date format

# %%
test_data = test_data.astype({'predicted_clear_date':'int32','posting_date':'int32','document_create_date':'int32','due_in_date':'int32','baseline_create_date':'int32'})

# %%
test_data['predicted_clear_date']=test_data['predicted_clear_date'].apply(dt.datetime.fromordinal)
test_data['posting_date']=test_data['posting_date'].apply(dt.datetime.fromordinal)
test_data['document_create_date']=test_data['document_create_date'].apply(dt.datetime.fromordinal)
test_data['due_in_date']=test_data['due_in_date'].apply(dt.datetime.fromordinal)
test_data['baseline_create_date']=test_data['baseline_create_date'].apply(dt.datetime.fromordinal)
test_data.head()
# Out:
#     USD  business_code        doc_id posting_date document_create_date  \
# 14  1.0         9179.0  1.930630e+09   2020-03-11           2020-03-10
# 15  1.0         9179.0  1.930733e+09   2020-04-02           2020-04-02
# 22  1.0         9179.0  1.930834e+09   2020-04-29           2020-04-29
# 35  1.0         9179.0  1.930643e+09   2020-03-12           2020-03-12
# 54  1.0         9179.0  1.930724e+09   2020-03-31           2020-03-31
#
#    due_in_date  total_open_amount baseline_create_date  cust_payment_terms  \
# 14  2020-03-26           14169.42           2020-03-11               405.0
# 15  2020-04-17           64394.42           2020-04-02               405.0
# 22  2020-05-14           25333.15           2020-04-29              3025.0
# 35  2020-03-27            2183.30           2020-03-12              4035.0
# 54  2020-04-15             212.41           2020-03-31              4035.0
#
#       invoice_id  delay predicted_clear_date  bucket_vals
# 14  1.930630e+09      2           2020-03-28  (0-15) Days
# 15  1.930733e+09      3           2020-04-20  (0-15) Days
# 22  1.930834e+09      0           2020-05-14   (<=0) Days
# 35  1.930643e+09     10           2020-04-06  (0-15) Days
# 54  1.930724e+09      3           2020-04-18  (0-15) Days

# %%
test_data.dtypes
# Out:
# USD                            float64
# business_code                  float64
# doc_id                         float64
# posting_date            datetime64[ns]
# document_create_date    datetime64[ns]
# due_in_date             datetime64[ns]
# total_open_amount              float64
# baseline_create_date    datetime64[ns]
# cust_payment_terms             float64
# invoice_id                     float64
# delay                            int32
# predicted_clear_date    datetime64[ns]
# bucket_vals                     object
# dtype: object

# %%
test_data.head()
# Out:
#     USD  business_code        doc_id posting_date document_create_date  \
# 14  1.0         9179.0  1.930630e+09   2020-03-11           2020-03-10
# 15  1.0         9179.0  1.930733e+09   2020-04-02           2020-04-02
# 22  1.0         9179.0  1.930834e+09   2020-04-29           2020-04-29
# 35  1.0         9179.0  1.930643e+09   2020-03-12           2020-03-12
# 54  1.0         9179.0  1.930724e+09   2020-03-31           2020-03-31
#
#    due_in_date  total_open_amount baseline_create_date  cust_payment_terms  \
# 14  2020-03-26           14169.42           2020-03-11               405.0
# 15  2020-04-17           64394.42           2020-04-02               405.0
# 22  2020-05-14           25333.15           2020-04-29              3025.0
# 35  2020-03-27            2183.30           2020-03-12              4035.0
# 54  2020-04-15             212.41           2020-03-31              4035.0
#
#       invoice_id  delay predicted_clear_date  bucket_vals
# 14  1.930630e+09      2           2020-03-28  (0-15) Days
# 15  1.930733e+09      3           2020-04-20  (0-15) Days
# 22  1.930834e+09      0           2020-05-14   (<=0) Days
# 35  1.930643e+09     10           2020-04-06  (0-15) Days
# 54  1.930724e+09      3           2020-04-18  (0-15) Days

# %%
test_data.reset_index(drop=True)
# Out:
#       USD  business_code        doc_id posting_date document_create_date  \
# 0     1.0         9179.0  1.930630e+09   2020-03-11           2020-03-10
# 1     1.0         9179.0  1.930733e+09   2020-04-02           2020-04-02
# 2     1.0         9179.0  1.930834e+09   2020-04-29           2020-04-29
# 3     1.0         9179.0  1.930643e+09   2020-03-12           2020-03-12
# 4     1.0         9179.0  1.930724e+09   2020-03-31           2020-03-31
# ...   ...            ...           ...          ...                  ...
# 9639  1.0         9179.0  1.930809e+09   2020-04-21           2020-04-21
# 9640  1.0         9179.0  1.930630e+09   2020-03-11           2020-03-10
# 9641  1.0         9179.0  1.930660e+09   2020-03-16           2020-03-16
# 9642  1.0         9179.0  1.930795e+09   2020-04-16           2020-04-16
# 9643  0.0          737.0  2.960618e+09   2020-03-08           2020-03-09
#
#      due_in_date  total_open_amount baseline_create_date  cust_payment_terms  \
# 0     2020-03-26           14169.42           2020-03-11               405.0
# 1     2020-04-17           64394.42           2020-04-02               405.0
# 2     2020-05-14           25333.15           2020-04-29              3025.0
# 3     2020-03-27            2183.30           2020-03-12              4035.0
# 4     2020-04-15             212.41           2020-03-31              4035.0
# ...          ...                ...                  ...                 ...
# 9639  2020-05-06           14467.62           2020-04-21               405.0
# 9640  2020-03-26           27375.05           2020-03-11              4035.0
# 9641  2020-03-31           36176.09           2020-03-16              3025.0
# 9642  2020-05-01            1898.90           2020-04-16              3025.0
# 9643  2020-03-26          126423.29           2020-03-16               732.0
#
#         invoice_id  delay predicted_clear_date  bucket_vals
# 0     1.930630e+09      2           2020-03-28  (0-15) Days
# 1     1.930733e+09      3           2020-04-20  (0-15) Days
# 2     1.930834e+09      0           2020-05-14   (<=0) Days
# 3     1.930643e+09     10           2020-04-06  (0-15) Days
# 4     1.930724e+09      3           2020-04-18  (0-15) Days
# ...            ...    ...                  ...          ...
# 9639  1.930809e+09      1           2020-05-07  (0-15) Days
# 9640  1.930630e+09     10           2020-04-05  (0-15) Days
# 9641  1.930660e+09      7           2020-04-07  (0-15) Days
# 9642  1.930795e+09      0           2020-05-01   (<=0) Days
# 9643  2.960618e+09      4           2020-03-30  (0-15) Days
#
# [9644 rows x 13 columns]

# %%
# test_data.to_csv('file_name.csv')
